# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('F:\\Machine Learning\\ML Udemy\\0_Course Notebooks\\05-Seaborn\\dm_office_sales.csv')

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
plt.figure(figsize = (8,8), dpi = 100)
sns.scatterplot(x = 'salary', y= 'sales', data = df, hue = 'level of education', palette = 'Dark2', size = 'training level')
# BASIC x, y and data.
# s = 200 <---- size of the dots
# alpha = 0.2 <---- transparency
# style = 'level of education' <---- another style for 'level od education data

plt.savefig('0_seaborn.jpeg')
