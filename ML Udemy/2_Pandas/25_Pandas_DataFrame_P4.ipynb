# %%
import numpy as np
import pandas as pd

df = pd.read_csv('F:\\Machine Learning\\ML Udemy\\Course Notebooks\\03-Pandas\\tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
# If we want a column to became the index of our DataFrame, we use .set_index

df = df.set_index('Payment ID')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
# Resetting the index
df = df.reset_index()
df.head()
# Out:
#    index Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0      0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1      1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2      2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3      3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4      4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322
# 3             11.84    Nathaniel Harris  4676137647685994
# 4              6.15        Tonya Carter  4832732618637221

# %%
df = df.set_index('Payment ID')
df.head()
# Out:
#             index  total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959         0       16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608         1       10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458         2       21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260         3       23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251         4       24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
# Display all the information of a certain row using his index number:
# .iloc
df.iloc[0]
# Out:
# index                                0
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
# Display all the information of a certain row using his label name index:
# .loc, WITHOUT THE i
df.loc['Sun2959']
# Out:
# index                                0
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
# We can use slicing aswell

df.iloc[0:4]
# Out:
#             index  total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959         0       16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608         1       10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458         2       21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260         3       23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
# Calling multiple rows with the names of their labels

df.loc[['Sun2959', 'Sun5260']]
# Out:
#             index  total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959         0       16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260         3       23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
# IN THIS CASE WE DIDN'T ESPECIFY THE AXIS BECAUSE .drop has x = 0 by default.
# ALSO is important to note that we can not use indexing number. For this example we can not
# write df.drop(0, x = 0). We need to provide the actual index name.

df = df.drop('Sun2959')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4756/474319230.py in <module>
#       3 # write df.drop(0, x = 0). We need to provide the actual index name.
#       4
# ----> 5 df = df.drop('Sun2959')
#
# C:\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\Python39\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4899                 weight  1.0     0.8
#    4900         """
# -> 4901         return super().drop(
#    4902             labels=labels,
#    4903             axis=axis,
#
# ...

# %%
df.head()
# Out:
#             index  total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608         1       10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458         2       21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260         3       23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251         4       24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679         5       25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# Sun4458                 7.00    Travis Walters  6011812112971322
# Sun5260                11.84  Nathaniel Harris  4676137647685994
# Sun2251                 6.15      Tonya Carter  4832732618637221
# Sun9679                 6.32        Erik Smith   213140353657882

# %%
df
# Out:
#             index  total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608         1       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458         2       21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260         3       23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251         4       24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679         5       25.29  4.71    Male     No   Sun  Dinner     4
# ...           ...         ...   ...     ...    ...   ...     ...   ...
# Sat2657       239       29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766       240       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       241       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         242       17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       243       18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# ...

# %%
one_row = df.iloc[0]
one_row
# Out:
# index                              1
# total_bill                     10.34
# tip                             1.66
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                3.45
# Payer Name            Douglas Tucker
# CC Number           4478071379779230
# Name: Sun4608, dtype: object

# %%
df = df.append(one_row)

# %%
df
# Out:
#             index  total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608         1       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458         2       21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260         3       23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251         4       24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679         5       25.29  4.71    Male     No   Sun  Dinner     4
# ...           ...         ...   ...     ...    ...   ...     ...   ...
# Sat1766       240       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       241       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         242       17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       243       18.78  3.00  Female     No  Thur  Dinner     2
# Sun4608         1       10.34  1.66    Male     No   Sun  Dinner     3
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# ...
