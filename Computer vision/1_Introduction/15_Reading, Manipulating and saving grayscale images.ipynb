# %%
import numpy as np
import matplotlib.pyplot as plt

im = plt.imread(r'F:\\Machine Learning\\Computer vision\\1_Introduction\\15_albert_einstein.jpg')

# %%
im
# Out:
# array([[85, 85, 85, ..., 62, 62, 62],
#        [85, 85, 85, ..., 64, 65, 64],
#        [85, 85, 85, ..., 59, 59, 58],
#        ...,
#        [36, 42, 42, ..., 36, 42, 47],
#        [29, 37, 37, ..., 36, 43, 44],
#        [33, 40, 37, ..., 35, 43, 42]], dtype=uint8)

# %%
type(im)
# Out:
# numpy.ndarray

# %%
im.shape
# Out:
# (949, 728)

# %%
im.dtype

# uint8 = unsignedinteger 8 bits
# Out:
# dtype('uint8')

# %%
plt.figure(figsize = (10,10), dpi = 100)
plt.imshow(im, cmap = 'gray', )

# %%
im[23,]
# Out:
# array([89, 89, 89, 87, 85, 83, 83, 83, 85, 85, 84, 83, 82, 81, 81, 81, 80,
#        80, 80, 81, 81, 82, 82, 82, 87, 87, 87, 86, 84, 82, 80, 79, 82, 81,
#        80, 80, 80, 80, 81, 82, 78, 79, 81, 83, 84, 84, 84, 84, 86, 86, 86,
#        86, 86, 84, 83, 82, 87, 88, 87, 85, 86, 89, 88, 85, 83, 83, 83, 82,
#        82, 81, 81, 81, 77, 79, 80, 78, 78, 81, 81, 79, 77, 77, 76, 76, 76,
#        77, 79, 81, 79, 78, 76, 75, 74, 75, 76, 77, 79, 79, 79, 79, 79, 79,
#        79, 79, 85, 82, 80, 81, 79, 76, 76, 79, 77, 77, 78, 79, 80, 80, 80,
#        80, 78, 80, 81, 80, 77, 74, 72, 71, 77, 79, 75, 74, 75, 72, 71, 79,
#        79, 77, 75, 76, 78, 78, 75, 71, 72, 77, 77, 73, 77, 84, 82, 72, 74,
#        77, 73, 73, 83, 83, 73, 68, 74, 72, 72, 73, 75, 75, 72, 69, 68, 67,
#        69, 73, 73, 70, 69, 71, 65, 69, 74, 76, 76, 73, 71, 70, 71, 72, 76,
#        78, 74, 68, 67, 70, 70, 71, 72, 73, 73, 73, 73, 72, 75, 79, 77, 76,
# ...

# %%
im2 = im.copy()

# %%
im2[13:200,25:200] = 255
plt.imshow(im2, cmap = 'gray')
plt.imsave(r'F:\\Machine Learning\\Computer vision\\1_Introduction\\15_albert_einstein_modified.jpg', arr = im2, cmap = 'gray')
