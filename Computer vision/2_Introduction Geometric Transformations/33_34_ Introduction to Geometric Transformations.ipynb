# %%
# Sometimes the number of images we have for convolutional neural networks are not sufficient, in this case we can translate, rotate or scale the same image 
# to provide our model more pictures. This technique is called Data Augmentation. It's probed this improve convolutional neural networks.

# Not have enough variety or maybe we have few data(images).

# %%
# Zoom in cameras use scale up images.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

grayIm = (r'F:\\Machine Learning\\Computer vision\\1_Introduction\\15_albert_einstein.jpg') 
coloIm = (r'F:\\Machine Learning\\Computer vision\\1_Introduction\\tulips.jpg')

# %%
gIm = cv2.imread(grayIm, cv2.IMREAD_GRAYSCALE)
cIm = cv2.imread(coloIm)

# %%
plt.imshow(cIm[:,:,::-1])

# %%
plt.imshow(gIm, cmap = 'gray')

# %%
gIm_resz = cv2.resize(src = gIm, fx = 2, fy = 0.5, dsize = None)

# %%
plt.imshow(gIm_resz, cmap = 'gray')

# %%
gIm.shape
# Out:
# (949, 728)

# %%
gIm_resz.shape
# Out:
# (474, 1456)
