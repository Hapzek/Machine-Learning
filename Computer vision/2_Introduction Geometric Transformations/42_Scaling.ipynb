# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

grayIm = (r'F:\\Machine Learning\\Computer vision\\1_Introduction\\15_albert_einstein.jpg') 
coloIm = (r'F:\\Machine Learning\\Computer vision\\1_Introduction\\tulips.jpg')

gIm = cv2.imread(grayIm, cv2.IMREAD_GRAYSCALE)
cIm = cv2.imread(coloIm)

# %%
P = np.array([2,4])

Sx,Sy = 2,2

# %%
S = np.array([[Sx,0], [0,Sy]])

# %%
S
# Out:
# array([[2, 0],
#        [0, 2]])

# %%
P_dash = S.dot(P)

P_dash
# Out:
# array([4, 8])

# %%
plt.imshow(gIm, cmap = 'gray')

# %%
rows = gIm.shape[0]
col = gIm.shape[1]

# %%
rows
# Out:
# 949

# %%
col
# Out:
# 728

# %%
gIm2 = np.zeros((rows, col), dtype = 'uint8')

# %%
plt.imshow(gIm2, cmap = 'gray')

# %%
for i in range (rows):
    for j in range (col):
        gIm2[i,j] = gIm[i,j]

# %%
plt.imshow(gIm2, cmap = 'gray')

# %%
for i in range (rows):
    for j in range (col):
        gIm2[rows - i - 1,j] = gIm[i,j]

# %%
plt.imshow(gIm2, cmap = 'gray')

# %%
from random import shuffle

# %%
RAS = ["Sheccid", "Jesus", "Juan_Carlos", "Xavi", "Brandon", "Edgar", "su_servilleta"]

shuffle(RAS)
RAS
# Out:
# ['su_servilleta',
#  'Juan_Carlos',
#  'Sheccid',
#  'Brandon',
#  'Jesus',
#  'Xavi',
#  'Edgar']
